# %% [markdown]
# # How to run the code

# %% [markdown]
# In order to run the code you need to run a R kernel:
#
# Install R and Jupyter:
# - Make sure R is installed on your system.
# - In R, install the IRKernel for R: `install.packages('IRkernel')`.
#
# Select R Kernel:
# - Open Jupyter, create a new notebook and from the **Kernel** menu, select **R** (this will start the R kernel).
#
# Run Your Code:
# - You can now run R code in the notebook.

# %% [markdown]
# # Imports

# %%
library(quantmod)
library(xts)
library(rumidas)
library(rugarch)
library(tseries)
library(forecast)
library(aTSA)
library(zoo)

# %% [markdown]
# # Problem statement

# %% [markdown]
# This project investigates whether public attention to renewable energy influences financial market volatility. As a quantifiable proxy for public interest, Google Trends data provides a useful tool for exploring this relationship empirically. Rather than analyzing a broad renewable energy index, the study focuses on the leading wind turbine manufacturer Vestas, allowing for a more targeted analysis.
#
# The central research question is:
# “Can search interest in renewable energy, as measured by Google Trends data, affect market uncertainty and, by proxy, affect the stock price volatility of the wind turbine company Vestas?”
#
#
# The initial hypothesis is that increased public interest in renewable energy is positively correlated with stock price volatility. This assumption is based on the idea that heightened search activity often coincides with both positive and negative news or developments that increase investor uncertainty and lead to greater price fluctuations. However, the direction and strength of this relationship are uncertain, motivating the need for an empirical analysis.

# %% [markdown]
# # Data

# %% [markdown]
# ## Read datasets

# %% [markdown]
# As mentioned in the problem statement section, the data used was Google Trends data and financial data from the wind turbine company Vestas.

# %% [markdown]
# ### Google data

# %% [markdown]
# For the Google Trends data set, the group found a publicly available data set for Monthly Google Trends search volumes for keywords related to renewable energy. This is available via the International Energy Agency, and contains search volume data for 40 energy-related terms across 45 countries. The data set contains data from January 2010 to August 2022.

# %%
google_data <- read.csv("google_data.csv", header = TRUE, stringsAsFactors = FALSE)

# %% [markdown]
# ### Vestas stock price data

# %% [markdown]
# To obtain financial data from Vestas, the group used the built-in function in R-code that retrieves historical financial data from the same period as the Google data, from Yahoo Finance.

# %%
symbol <- "VWS.CO"  # Vestas Wind Systems (Copenhagen Stock Exchange)
start_date <- as.Date("2010-01-01")
end_date <- as.Date("2022-08-31")
getSymbols(symbol, src = "yahoo", from = start_date, to = end_date)
vestas_data <- Cl(get(symbol))  # Cl() extracts the closing prices
vestas_df <- data.frame(date = index(vestas_data), price = coredata(vestas_data))
# Out:
# [1] "VWS.CO"

# %% [markdown]
# ## Clean and prepare the data

# %% [markdown]
# ### Google data

# %% [markdown]
# #### Filtering the dataset

# %% [markdown]
# The data was cleaned by removing less relevant search words and countries outside of Europe. The search words left in the dataset after this cleaning are given in the list below.
# * Batteries
# * Electric vehicle
# * Electricity
# * Electrification
# * Geothermal
# * Heat pump
# * Hydroelectricity
# * Hydrogen
# * Nuclear
# * Offshore wind
# * Solar power
# * Train
# * Wind power
#
# The cleaning of the Google trends data set also included selecting the relevant columns and removing the rest, to minimize redundant data. Further, the date format was converted to a proper date format, and aggregated to get an average for Europe.

# %%
# Select only the relevant columns
google_data <- google_data[, c("country", "countryISO", "techSector", "year", "value")]

# Define the sectors you're interested in
tech_sectors <- c("Batteries", "Electric vehicle", "Electricity", "Electrification", 
                  "Geothermal", "Heat pump", "Hydroelectricity", "Hydrogen", 
                  "Nuclear", "Offshore wind", "Solar power", "Train", "Wind power")

# Filter for the selected tech sectors
google_data <- google_data[google_data$techSector %in% tech_sectors, ]

european_countries <- c("France", "Italy", "Sweden", "Austria", "Turkey", 
                         "Slovak Republic", "Belgium", "United Kingdom", 
                         "Portugal", "Ireland", "Switzerland", "Finland", 
                         "Norway", "Germany", "Netherlands")
google_data_european <- google_data[google_data$country %in% european_countries, ]


colnames(google_data)[colnames(google_data) == "year"] <- "date"

# Convert the date column into a proper date format
google_data$date <- as.Date(paste0(substr(google_data$date, 1, 2), 
                                   "-", substr(google_data$date, 3, 4), 
                                   "-01"), 
                            format = "%y-%m-%d")
# Convert back to Date type
google_data$date <- as.Date(google_data$date)

colnames(google_data_european)[colnames(google_data_european) == "year"] <- "date"
# Convert the date column into a proper date format for the European data
google_data_european$date <- as.Date(paste0(substr(google_data_european$date, 1, 2), 
                                             "-", substr(google_data_european$date, 3, 4), 
                                             "-01"), 
                                      format = "%y-%m-%d")
# Convert back to Date type for the European data
google_data_european$date <- as.Date(google_data_european$date)

# Aggregate: Compute average value for each month
google_monthly_avg <- aggregate(value ~ date, data = google_data, FUN = mean)
google_data_european_monthly_avg <- aggregate(value ~ date, data = google_data_european, FUN = mean)

head(google_monthly_avg)
head(google_data_european_monthly_avg)
# Out:
#   date       value
# 1 2010-01-01 4.682794
# 2 2010-02-01 4.591593
# 3 2010-03-01 4.745969
# 4 2010-04-01 4.914769
# 5 2010-05-01 4.848954
# 6 2010-06-01 4.842765
#   date       value
# 1 2010-01-01 4.646908
# 2 2010-02-01 4.462741
# 3 2010-03-01 4.785163
# 4 2010-04-01 5.008614
# 5 2010-05-01 4.479021
# 6 2010-06-01 4.890323

# %% [markdown]
# #### European data

# %%
par(bg = "white")
plot(google_monthly_avg$date, google_monthly_avg$value, type = "l", col = "blue",
     xlab = "Year", ylab = "Average Value", main = "Monthly Average of Renewable Energy Trends")
# Add grid for better readability
grid()

par(bg = "white")
plot(google_data_european_monthly_avg$date, google_data_european_monthly_avg$value, type = "l", col = "blue",
     xlab = "Year", ylab = "Average Value", main = "Monthly Average of European Renewable Energy Trends")
# Add grid for better readability
grid()
# Out:
# Plot with title “Monthly Average of Renewable Energy Trends”
# Plot with title “Monthly Average of European Renewable Energy Trends”

# %% [markdown]
# The plots show a clearer seasonal pattern when we focus only on European search trends. The first plot includes data from countries outside Europe, while the second plot only shows data from European countries. Since Vestas is a danish company, we will focus on the data from European countries for the rest of the report.

# %% [markdown]
# #### Log change

# %% [markdown]
# By using log change, the data becomes more normalized, allowing for easier comparison of percentage changes over time. Log changes also reduce the impact of extreme values, making the analysis more robust.

# %%
# Calculate the log returns (difference of log values)
google_monthly_european_log_change <- diff(log(google_data_european_monthly_avg$value))

# Create a new data frame with the corresponding dates and returns
google_monthly_european_log_change <- data.frame(date = google_data_european_monthly_avg$date[-1], 
                                                    log_change = google_monthly_european_log_change)

# View the first few rows of the new data frame
head(google_monthly_european_log_change)

# Plot the log change over time
par(bg = "white")
plot(google_monthly_european_log_change$date, google_monthly_european_log_change$log_change, 
     type = "l", col = "blue", 
     xlab = "Date", ylab = "Log Change", 
     main = "Google Monthly Log Change")

# Add grid for better readability
grid()
# Out:
#   date       log_change
# 1 2010-02-01 -0.04043891
# 2 2010-03-01  0.06975688
# 3 2010-04-01  0.04563916
# 4 2010-05-01 -0.11175477
# 5 2010-06-01  0.08785398
# 6 2010-07-01  0.01392989
# Plot with title “Google Monthly Log Change”

# %% [markdown]
# ### Vestas stock price data

# %% [markdown]
# First, the code plots the data for visualization. Next, the code calculates the daily log returns by taking the difference in the natural logarithm of consecutive stock prices. These returns are stored in a new data frame alongside their corresponding dates and plotted to visualize fluctuations in daily returns.

# %%
# Rename the column for easier access
colnames(vestas_df)[2] <- "price"
vestas_df$date <- as.Date(vestas_df$date)

# %%
# Plot Vestas stock price over time
par(bg = "white")
plot(vestas_df$date, vestas_df$price, type = "l", col = "red",
     xlab = "Year", ylab = "Stock Price (DKK)", 
     main = "Vestas Stock Price (2010 - 2022)")
# Add grid for better readability
grid()
# Out:
# Plot with title “Vestas Stock Price (2010 - 2022)”

# %%
# Calculate the log returns (difference of log prices)
vestas_daily_returns <- diff(log(vestas_df$price))

# Create a new data frame with the corresponding dates and returns
vestas_returns_df <- data.frame(date = vestas_df$date[-1], log_return = vestas_daily_returns)

# View the data frame
head(vestas_returns_df)

# Plot the log returns over time
par(bg = "white")
plot(vestas_returns_df$date, vestas_returns_df$log_return, type = "l", col = "red", 
     xlab = "Date", ylab = "Log Return", 
     main = "Vestas Daily Log Returns (2010 - 2022)")

# Add grid for better readability
grid()
# Out:
#   date       log_return
# 1 2010-01-05 -0.030894096
# 2 2010-01-06 -0.012503999
# 3 2010-01-07  0.008145356
# 4 2010-01-08 -0.004691162
# 5 2010-01-11  0.030866706
# 6 2010-01-12 -0.037155999
# Plot with title “Vestas Daily Log Returns (2010 - 2022)”

# %% [markdown]
# ### Transfrom data to xts

# %% [markdown]
# Both trend data and financial data is converted into xts time-series objects, allowing for easier alignment and analysis of the two datasets in time-series models.

# %% [markdown]
# #### European Google data

# %%
google_monthly_avg_xts <- xts(google_monthly_european_log_change$log_change, order.by = google_monthly_european_log_change$date)
colnames(google_monthly_avg_xts) <- "value"
head(google_monthly_avg_xts)
# Out:
#                  value
# 2010-02-01 -0.04043891
# 2010-03-01  0.06975688
# 2010-04-01  0.04563916
# 2010-05-01 -0.11175477
# 2010-06-01  0.08785398
# 2010-07-01  0.01392989

# %% [markdown]
# #### Vestas log return data

# %%
vestas_daily_returns_xts <- xts(vestas_returns_df$log_return, order.by = vestas_returns_df$date)
colnames(vestas_daily_returns_xts) <- "return"
head(vestas_daily_returns_xts)
# Out:
#                  return
# 2010-01-05 -0.030894096
# 2010-01-06 -0.012503999
# 2010-01-07  0.008145356
# 2010-01-08 -0.004691162
# 2010-01-11  0.030866706
# 2010-01-12 -0.037155999

# %% [markdown]
# # Empirical Analysis

# %% [markdown]
# ## Data understanding

# %% [markdown]
# #### Normality

# %%
par(bg = "white")
hist(vestas_returns_df$log_return, breaks = 50, probability = TRUE, 
     main = "Histogram of Vestas Log Returns", xlab = "Log Return", col = "lightblue")

# Overlay a normal density curve
curve(dnorm(x, mean = mean(vestas_returns_df$log_return), 
            sd = sd(vestas_returns_df$log_return)), 
      col = "red", lwd = 2, add = TRUE)

jarque.bera.test(vestas_returns_df$log_return)
# Out:
# 	Jarque Bera Test
#
# data:  vestas_returns_df$log_return
# X-squared = 11842, df = 2, p-value < 2.2e-16
# Plot with title “Histogram of Vestas Log Returns”

# %%
# 1. Create the histogram for Google monthly average values
par(bg = "white")
hist(google_monthly_european_log_change$log_change,  # Using the 'log_change' column from the xts object
     breaks = 50,                   # Number of bins
     probability = TRUE,            # Scale the y-axis to probability density
     main = "Histogram of Google Monthly Averages",  # Title of the plot
     xlab = "Google Monthly Average",  # X-axis label
     col = "lightblue")             # Color of the bars

# 2. Overlay the normal density curve based on the Google data
curve(dnorm(x, mean = mean(google_monthly_european_log_change$log_change),  # Mean of the data
            sd = sd(google_monthly_european_log_change$log_change)),        # Standard deviation of the data
      col = "red",                    # Color of the curve
      lwd = 2,                        # Line width
      add = TRUE)                     # Add the curve on top of the histogram

jarque.bera.test(google_monthly_european_log_change$log_change)
# Out:
# 	Jarque Bera Test
#
# data:  google_monthly_european_log_change$log_change
# X-squared = 590.13, df = 2, p-value < 2.2e-16
# Plot with title “Histogram of Google Monthly Averages”

# %% [markdown]
# Both histograms appear roughly bell-shaped but deviate from perfect normality, showing heavier tails and slight asymmetry. The Jarque-Bera tests confirm that the distributions are not strictly normal (p-value < 2.2e-16), indicating mild skewness and excess kurtosis — patterns commonly observed in financial and economic time series

# %% [markdown]
# #### Autocorrelation

# %%
par(bg = "white")
acf(vestas_returns_df$log_return, main = "ACF of Vestas Log Returns")
pacf(vestas_returns_df$log_return, main = "PACF of Vestas Log Returns")
# Out:
# Plot with title “ACF of Vestas Log Returns”
# Plot with title “PACF of Vestas Log Returns”

# %% [markdown]
# The ACF plot shows the autocorrelation of Vestas log returns over different lags, indicating no significant autocorrelation for any lag. The PACF plot highlights partial autocorrelations, suggesting minimal direct relationships between returns at higher lags. Both plots confirm weak serial dependence in the data.

# %% [markdown]
# #### Stationarity

# %%
# Test for stationarity on log returns
adf.test(vestas_returns_df$log_return)
# Out:
# Augmented Dickey-Fuller Test
# alternative: stationary
#
# Type 1: no drift no trend
#       lag   ADF p.value
#  [1,]   0 -57.3    0.01
#  [2,]   1 -39.0    0.01
#  [3,]   2 -33.8    0.01
#  [4,]   3 -29.8    0.01
#  [5,]   4 -25.8    0.01
#  [6,]   5 -23.6    0.01
#  [7,]   6 -21.5    0.01
#  [8,]   7 -20.1    0.01
#  [9,]   8 -18.5    0.01
# Type 2: with drift no trend
#       lag   ADF p.value
#  [1,]   0 -57.3    0.01
#  [2,]   1 -39.0    0.01
#  [3,]   2 -33.8    0.01
#  [4,]   3 -29.8    0.01
#  [5,]   4 -25.8    0.01
#  [6,]   5 -23.6    0.01
#  [7,]   6 -21.5    0.01
#  [8,]   7 -20.1    0.01
#  [9,]   8 -18.5    0.01
# Type 3: with drift and trend
#       lag   ADF p.value
#  [1,]   0 -57.3    0.01
#  [2,]   1 -39.0    0.01
#  [3,]   2 -33.8    0.01
#  [4,]   3 -29.8    0.01
#  [5,]   4 -25.8    0.01
#  [6,]   5 -23.6    0.01
#  [7,]   6 -21.6    0.01
#  [8,]   7 -20.2    0.01
#  [9,]   8 -18.6    0.01
# ----
# Note: in fact, p.value = 0.01 means p.value <= 0.01

# %%
# Test for stationarity on google log change
adf.test(google_monthly_european_log_change$log_change)
# Out:
# Augmented Dickey-Fuller Test
# alternative: stationary
#
# Type 1: no drift no trend
#      lag    ADF p.value
# [1,]   0 -11.28    0.01
# [2,]   1 -10.42    0.01
# [3,]   2  -7.73    0.01
# [4,]   3  -7.35    0.01
# [5,]   4  -6.51    0.01
# Type 2: with drift no trend
#      lag    ADF p.value
# [1,]   0 -11.32    0.01
# [2,]   1 -10.49    0.01
# [3,]   2  -7.81    0.01
# [4,]   3  -7.50    0.01
# [5,]   4  -6.65    0.01
# Type 3: with drift and trend
#      lag    ADF p.value
# [1,]   0 -11.31    0.01
# [2,]   1 -10.51    0.01
# [3,]   2  -7.85    0.01
# [4,]   3  -7.52    0.01
# [5,]   4  -6.72    0.01
# ----
# Note: in fact, p.value = 0.01 means p.value <= 0.01

# %% [markdown]
# The ADF test indicates that the log changes in both the Google data and Vestas stock are stationary. The p-values for all test types (no drift, with drift, and with drift and trend) are less than 0.01, meaning we reject the null hypothesis of non-stationarity. This confirms that the time series does not have a unit root and is suitable for modeling without further differencing.

# %% [markdown]
# #### Heteroskedasticity

# %%
# Choose a rolling window size for intra-month volatility
window_size <- 90
par(bg = "white")
# Calculate the rolling standard deviation (volatility) using rollapply
rolling_volatility_intra_month <- rollapply(vestas_daily_returns_xts, 
                                            width = window_size, 
                                            FUN = sd, 
                                            align = "right", 
                                            fill = NA)

# Plot the rolling volatility
plot(index(rolling_volatility_intra_month), rolling_volatility_intra_month, 
     type = "l", col = "blue", 
     xlab = "Date", ylab = "Intra-month Volatility (Standard Deviation)", 
     main = "Rolling Volatility of Vestas Daily Returns (3-month window)")

grid()
# Out:
# Plot with title “Rolling Volatility of Vestas Daily Returns (3-month window)”

# %%
par(bg = "white")
plot(vestas_returns_df$date, vestas_returns_df$log_return^2, 
     type = "l", col = "blue", 
     xlab = "Date", ylab = "Squared Log Return", 
     main = "Squared Log Returns")
grid()
# Out:
# Plot with title “Squared Log Returns”

# %%
par(bg = "white")
# Step 1: Fit an ARIMA model to your data (you can adjust the order)
model <- arima(vestas_daily_returns_xts, order = c(10, 0, 0))  # Example AR(5) model

# Step 2: Perform Engle’s ARCH test
arch_result <- arch.test(model)

# Step 3: View the results of the ARCH test
print(arch_result)

# Optional Step 4: Visualize residuals, squared residuals, and p-values of tests
arch.test(model, output = TRUE)
# Out:
# ARCH heteroscedasticity test for residuals
# alternative: heteroscedastic
#
# Portmanteau-Q test:
#      order   PQ  p.value
# [1,]     4 34.3 6.53e-07
# [2,]     8 45.0 3.73e-07
# [3,]    12 49.8 1.53e-06
# [4,]    16 61.0 3.56e-07
# [5,]    20 68.2 3.58e-07
# [6,]    24 79.1 8.40e-08
# Lagrange-Multiplier test:
#      order   LM p.value
# [1,]     4 7553       0
# [2,]     8 3595       0
# [3,]    12 2360       0
# [4,]    16 1730       0
# [5,]    20 1369       0
# [6,]    24 1115       0
#      order       PQ      p.value       LM p.value
# [1,]     4 34.27892 6.532091e-07 7553.268       0
# [2,]     8 44.97183 3.725498e-07 3595.150       0
# [3,]    12 49.77809 1.528246e-06 2359.977       0
# [4,]    16 60.98986 3.561832e-07 1730.349       0
# [5,]    20 68.19200 3.583953e-07 1369.446       0
# [6,]    24 79.12042 8.395949e-08 1115.051       0
# ARCH heteroscedasticity test for residuals
# alternative: heteroscedastic
#
# Portmanteau-Q test:
#      order   PQ  p.value
# [1,]     4 34.3 6.53e-07
# [2,]     8 45.0 3.73e-07
# [3,]    12 49.8 1.53e-06
# [4,]    16 61.0 3.56e-07
# [5,]    20 68.2 3.58e-07
# [6,]    24 79.1 8.40e-08
# Lagrange-Multiplier test:
#      order   LM p.value
# [1,]     4 7553       0
# [2,]     8 3595       0
# [3,]    12 2360       0
# [4,]    16 1730       0
# [5,]    20 1369       0
# [6,]    24 1115       0
# plot without title

# %% [markdown]
# The ARCH test results strongly indicate the presence of heteroskedasticity in the residuals, as shown by highly significant p-values in both the Portmanteau-Q and Lagrange Multiplier tests. This suggests that the variance of the residuals is time-dependent, justifying the use of GARCH-type models.

# %% [markdown]
# ## Garch-Midas

# %% [markdown]
# GARCH-MIDAS is a GARCH model that enables use of data with different frequencies, allowing the model to compare low-frequency macro data with high-frequency financial data. The model can therefore examine the effect of macroeconomic variables on a stock volatility. This makes it an ideal model for the project, as the Google Trends data is only available on a monthly basis.

# %% [markdown]
# ### Fitting the model

# %% [markdown]
# This part of the code aligns daily return data with monthly average data by trimming the daily data to match a specific time window. It first sets a starting point K months into the monthly data and updates the daily data to start from that date if needed. Then, it ensures the daily data doesn't extend beyond the last date of the monthly data. This prepares both datasets for consistent time alignment when fitting the model.

# %% [markdown]
# The code below iterates through different model configurations to fit GARCH-MIDAS models to Vestas stock returns data with Google Trends as the exogenous variable. It explores combinations of:
#
# - Window lengths (K values): 3, 6, 9, and 12 months
#     - K determines how many months of Google Trends data are used to model long-term volatility
#     - Longer windows capture more historical information but may include less relevant older data
#
# - Error distributions: Normal and Student-t
#     - Normal distribution assumes symmetric errors with lighter tails
#     - Student-t distribution allows for heavier tails to better capture extreme market movements
#
# - Lag weighting functions: Beta and Almon polynomial
#     - Beta function provides flexible weighting that can be monotonically decreasing or hump-shaped
#     - Almon polynomial imposes a more structured polynomial pattern on the lag weights
#
# Each combination is evaluated using AIC and BIC criteria to determine the optimal model specification.

# %%
K_values <- c(3, 6, 9, 12)
distributions <- c("norm", "std") #Removed "ged" because of error
lag_functions <- c("Beta", "Almon") #removed "expalmon" Because error

results <- list()

for (K in K_values) {
  for (dist in distributions) {
    for (lag_fun in lag_functions) {
      model_key <- paste0("K", K, "_", dist, "_", lag_fun)
      cat(sprintf("Fitting GM: %s\n", model_key))
      
      tryCatch({
        # Adjust starting point for K
        start_monthly <- index(google_monthly_avg_xts)[1]
        new_start_date <- as.Date(seq(start_monthly, by = "month", length.out = K + 1)[K + 1])
        
        adj_returns <- vestas_daily_returns_xts
        if (index(adj_returns)[1] < new_start_date) {
          adj_returns <- adj_returns[new_start_date <= index(adj_returns)]
        }
        
        # Align with end date
        end_monthly <- index(google_monthly_avg_xts)[length(google_monthly_avg_xts)]
        if (index(adj_returns)[length(adj_returns)] > end_monthly) {
          adj_returns <- adj_returns[index(adj_returns) <= end_monthly]
        }
        
        mv_m <- mv_into_mat(
          x = adj_returns$return,
          mv = google_monthly_avg_xts,
          K = K,
          type = "monthly"
        )
        
        model <- ugmfit(
          model = "GM",
          skew = "NO",
          distribution = dist,
          daily_ret = adj_returns$return,
          mv_m = mv_m,
          K = K,
          lag_fun = lag_fun
        )
        
        results[[model_key]] <- list(
          model = model,
          AIC = model$inf_criteria["AIC"],
          BIC = model$inf_criteria["BIC"]
        )
        
        cat(sprintf("AIC: %.2f | BIC: %.2f\n\n", model$inf_criteria["AIC"], model$inf_criteria["BIC"]))
        
      }, error = function(e) {
        cat(sprintf("Error in model %s: %s\n", model_key, e$message))
      })
    }
  }
}
# Out:
# Fitting GM: K3_norm_Beta
# AIC: -13147.24 | BIC: -13117.11
#
# Fitting GM: K3_norm_Almon
# AIC: -13146.52 | BIC: -13116.38
#
# Fitting GM: K3_std_Beta
# AIC: -17202.26 | BIC: -17166.10
#
# Fitting GM: K3_std_Almon
# AIC: -17202.25 | BIC: -17166.09
#
# Fitting GM: K6_norm_Beta
# AIC: -12916.46 | BIC: -12886.44
#
# Fitting GM: K6_norm_Almon
# AIC: -12927.23 | BIC: -12897.20
#
# Fitting GM: K6_std_Beta
# AIC: -16856.67 | BIC: -16820.64
#
# Fitting GM: K6_std_Almon
# AIC: -16856.61 | BIC: -16820.58
#
# Fitting GM: K9_norm_Beta
# AIC: -12706.43 | BIC: -12676.51
#
# Fitting GM: K9_norm_Almon
# AIC: -12709.03 | BIC: -12679.11
#
# Fitting GM: K9_std_Beta
# AIC: -16517.66 | BIC: -16481.76
#
# Fitting GM: K9_std_Almon
# AIC: -16516.46 | BIC: -16480.56
#
# Fitting GM: K12_norm_Beta
# AIC: -12427.17 | BIC: -12397.36
#
# Fitting GM: K12_norm_Almon
# AIC: -12426.22 | BIC: -12396.41
#
# Fitting GM: K12_std_Beta
# AIC: -16158.83 | BIC: -16123.06
#
# Fitting GM: K12_std_Almon
# AIC: -16158.66 | BIC: -16122.89

# %%
#find the best model
best_model <- NULL
best_aic <- Inf
best_bic <- Inf
best_model_key <- NULL
for (key in names(results)) {
  model_info <- results[[key]]
  if (model_info$AIC < best_aic) {
    best_aic <- model_info$AIC
    best_model <- model_info$model
    best_model_key <- key
  }
  if (model_info$BIC < best_bic) {
    best_bic <- model_info$BIC
  }
}
cat(sprintf("Best Model: %s\n", best_model_key))
cat(sprintf("Best AIC: %.2f\n", best_aic))
cat(sprintf("Best BIC: %.2f\n", best_bic))
# Print the best model summary
cat(sprintf("Best Model Summary:\n"))
#print summry.rumidas(best_model))
summary.rumidas(best_model)
# Out:
# Best Model: K3_std_Beta
# Best AIC: -17202.26
# Best BIC: -17166.10
# Best Model Summary:
#
# Coefficients:
#       Estimate Std. Error  t value Pr(>|t|) Sig.
# alpha   0.0329     0.0146   2.2580   0.0239   **
# beta    0.9649     0.0162  59.5910   0.0000  ***
# m      -6.3838     0.0740 -86.3156   0.0000  ***
# theta   1.5424     0.0306  50.4440   0.0000  ***
# w2      3.2527     0.5018   6.4822   0.0000  ***
# shape   3.8594     0.7010   5.5055   0.0000  ***
# ---
# Signif. codes: 0.01 '***', 0.05 '**', 0.1 '*'
#
# Obs.: 3060. Sample Period: 2010-05-03/2022-08-01
# MSE(%): 0.000952;  QLIKE: -6.132842

# %% [markdown]
# ### Comment on parameters

# %% [markdown]
# 1. **α (alpha) = 0.0329**
#    - **Interpretation**: Short-term volatility component. A positive value suggests recent shocks impact volatility, with a moderate sensitivity to past shocks.
#    - **Significance**: p-value = 0.0125 (**significant**), indicating short-term volatility in Vestas stock is influenced by recent returns.
#
# 2. **β (beta) = 0.9649**
#    - **Interpretation**: Persistence of volatility. Close to 1, indicating that volatility shocks persist over time.
#    - **Significance**: p-value = 0.0000 (**highly significant**), showing robust persistence of volatility.
#
# 3. **m = -6.3838**
#    - **Interpretation**: Long-term volatility lag parameter. A negative value suggests that higher Google Trends activity (public interest) is associated with **lower long-term volatility**.
#    - **Significance**: p-value = 0.0000 (**highly significant**), confirming the effect of lag structure on volatility.
#
# 4. **θ (theta) = 1.5424**
#    - **Interpretation**: Long-term volatility component. Positive value indicates that higher public attention to renewable energy (Google Trends) increases long-term volatility in Vestas stock.
#    - **Significance**: p-value = 0.0000 (**highly significant**), supporting the hypothesis that public interest drives long-term market uncertainty.
#
# 5. **w2 = 3.2528**
#    - **Interpretation**: Links short-term volatility (GARCH) to long-term volatility (MIDAS). Positive value suggests that long-term volatility driven by Google Trends significantly impacts short-term stock volatility.
#    - **Significance**: p-value = 0.0000 (**highly significant**), reinforcing the connection between short- and long-term volatility.
#
# 6. **Shape = 3.8594**
#    - **Interpretation**: Indicates the distribution shape of volatility. Positive value suggests fat tails, implying the volatility process is more prone to extreme events than a normal distribution.
#    - **Significance**: p-value = 0.0000 (**highly significant**), showing that extreme volatility events are more likely.

# %% [markdown]
# # Conclusion

# %% [markdown]
# The results show a statistically significant and positive relationship between public search interest in energy-related terms and the stock price volatility of Vestas. Specifically, the theta coefficient estimate of 1.54 is both economically large and statistically highly significant (p < 0.001), indicating that increased attention, as measured through Google Trends data, is strongly associated with heightened volatility in Vestas’ stock.
#
# This supports the notion that spikes in public interest often correspond with episodes of market uncertainty or reactions to external events such as policy announcements, climate discourse, or renewable energy developments. In such periods, elevated search activity may signal increased investor attention or informational shocks, which in turn can amplify trading volume and price fluctuations.
#
# This finding aligns with the initial hypothesis: greater public awareness and attention, especially during turbulent or transitional periods in the renewable energy sector, can influence market dynamics and increase volatility. Nonetheless, it’s important to note that while this variable is significant, it captures only part of the overall variation in volatility. Many other factors, such as macroeconomic conditions, institutional trading behavior, or broader market movements, also contribute substantially.
#
# Moreover, considering that around 85% of Vestas shares are held by institutional investors (https://www.vestas.com/en/investor/share-and-capital-structure/share-information#accordion-7647c6cd9b-item-2a7d04ede7), the driving forces behind price discovery are likely dominated by institutional actions. Thus, even if retail-driven search trends do correlate with volatility, we cannot make causal claims without further structural analysis. Correlation does not imply causation, both volatility and search trends might be reacting to a third, unobserved driver.

# %% [markdown]
# # Use of LLMs

# %% [markdown]
# ### Our Use Case vs. Experience and Learning Outcomes

# %% [markdown]
# #### 1. Supporting programming efforts and bug fixing
# - **Use case:**
#   Consulting ChatGPT & Grok for logical errors and syntax autocompletion (e.g., with Copilot)
#
# - **Outcome:**
#   Made programming and troubleshooting more efficient.
#   Although some output was unreliable and needed revision, we experienced the efficiency improvement as a net positive.

# %% [markdown]
# #### 2. Attempted to use for logical structure and empirical analysis
# - **Use case:**
#   Leveraging LLMs for structuring arguments and interpreting empirical findings
#
# - **Outcome:**
#   Quality of output was highly unpredictable and unreliable.
#   We did not end up using any of the suggested inputs, as sticking to the course material ensures a higher academic standard and best practice.

# %% [markdown]
# #### 3. Model output analysis reflections and suggestions
# - **Use case:**
#   Exploring further research directions or identifying methodological errors using LLM suggestions
#
# - **Outcome:**
#   LLM output was useful in presenting new ideas and questions we hadn’t yet considered.
#   However, many were erroneous or nonsensical and had to be manually checked and debunked.

# %% [markdown]
# # For next time

# %% [markdown]
# Next time, we should more clearly justify why we chose the GARCH-MIDAS framework over simpler volatility models, perhaps by comparing performance metrics like AIC/BIC against a plain GARCH or EGARCH benchmark. Considering incorporating additional macro-financial drivers (e.g., oil prices or interest rates) alongside Google Trends would likely strengthen explanatory power and improving figure captions and axis labels will make our visuals more readable. Finally, extending the scope through causal inference techniques, event-study analysis around policy announcements, or replicating the approach on similar renewable-energy firms would help verify the robustness and generalizability of our findings, so that we can use our results on a more general basis.
